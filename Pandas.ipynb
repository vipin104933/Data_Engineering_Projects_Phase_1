# %% [markdown]
# # pandas

# %% [raw]
# #pandas --> Panel Data
# Any data
# data frame- multiple rows and colonms
# built in on numpy

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.4.4'

# %% [markdown]
# # Series

# %%
## Creating series using tuple
t=(10,11,12)
d=pd.Series(t)
d
# Out:
# 0    10
# 1    11
# 2    12
# dtype: int64

# %%
## creating series using list
l1 = [45,78,56,445,78]
d= pd.Series(l1)
d
# Out:
# 0     45
# 1     78
# 2     56
# 3    445
# 4     78
# dtype: int64

# %%
l1=[[45,78,56,445,78],[1,2,3,4,5]]
d= pd.Series(l1)
d
# Out:
# 0    [45, 78, 56, 445, 78]
# 1          [1, 2, 3, 4, 5]
# dtype: object

# %%
# for list of lists series treat as a single element as a whole list

# %%
#import numpy as np
#d=pd.Series(np.array([[45,78,56,445,78],[1,2,3,4,5]]))
#d

# %%
## Creating series with array
import numpy as np
arr=np.array([1,2,3,4,5])
d1=pd.Series(arr)
d1
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int32

# %%
## Using Dictinaory
d={'a':1,'b':2,'c':3,'d':4}

# %%
d['a']
# Out:
# 1

# %%
b=pd.Series(d)

# %%
b
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
# index will be key of dict

# %%
b['c']
# Out:
# 3

# %%
d=pd.Series(np.arange(10,20))
d[1:5]
# Out:
# 1    11
# 2    12
# 3    13
# 4    14
# dtype: int32

# %% [markdown]
# # Dataframe

# %%
import pandas as pd

# %%
data=[['abc',1],['def',2],['ghi',3],['hij'],['klm','5']]

# %%
data
# Out:
# [['abc', 1], ['def', 2], ['ghi', 3], ['hij'], ['klm', '5']]

# %%
# dataframe is it tabulaor from of data

# %%
a=pd.DataFrame(data)
a
# Out:
#      0     1
# 0  abc     1
# 1  def     2
# 2  ghi     3
# 3  hij  None
# 4  klm     5

# %%
import numpy as np
d= pd.DataFrame(np.array([[45,78,56,445,78],[1,2,3,4,5]]))
d
# Out:
#     0   1   2    3   4
# 0  45  78  56  445  78
# 1   1   2   3    4   5

# %%
#d=pd.DataFrame(data,columns=['A','B','C','D','E']) ## CHANGING THE COL

# %%
d= pd.DataFrame(data,columns=['A','B'],index=['A','B','C','D','E']) ## CHANGING THE INDEX

# %%
d
# Out:
#      A     B
# A  abc     1
# B  def     2
# C  ghi     3
# D  hij  None
# E  klm     5

# %%
## DataFrame using Dictionary
data= {'name':['a','b','c','d','e','f'],'age':[45,12,48,25,12,56]}

# %%
d= pd.DataFrame(data)
d
# Out:
#   name  age
# 0    a   45
# 1    b   12
# 2    c   48
# 3    d   25
# 4    e   12
# 5    f   56

# %%
print(type(d))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
d.columns
# Out:
# Index(['name', 'age'], dtype='object')

# %%
d.columns=['Candidate','Age_in_years'] #changeing a col name

# %%
d
# Out:
#   Candidate  Age_in_years
# 0         a            45
# 1         b            12
# 2         c            48
# 3         d            25
# 4         e            12
# 5         f            56

# %%
d.columns
# Out:
# Index(['Candidate', 'Age_in_years'], dtype='object')

# %%
d.rename({'Age_in_years':"Age"},axis=1,inplace=True)

# %%
d
# Out:
#   Candidate  Age
# 0         a   45
# 1         b   12
# 2         c   48
# 3         d   25
# 4         e   12
# 5         f   56

# %%
import pandas as pd
import numpy as np

# %%
pwd
# Out:
# 'C:\\Users\\singh\\CDEWEE31AUG'

# %% [markdown]
# # csv file DataFrame

# %%
## reading the data from github
data=pd.read_csv('train.csv')

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
## checking the head part

data.head() #head() return first 5 rows
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.head(15)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
## checking the tail part
data.tail() #last 5 record
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
data.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data['Pclass'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
data['Cabin'].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
data.shape #shape is an atributes of the dataframe
# Out:
# (891, 12)

# %%
data.rename({'Sex':"Gender"},axis=1,inplace=True)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Gender       891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
## Describe give statistiscs of numerical variables
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
## describe with 'O' alphbet O not 0 statictics of categorical variables
data.describe(include='O')
# Out:
#                            Name Gender  Ticket    Cabin Embarked
# count                       891    891     891      204      889
# unique                      891      2     681      147        3
# top     Braund, Mr. Owen Harris   male  347082  B96 B98        S
# freq                          1    577       7        4      644

# %%
data[data['Age']==80]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#     Gender   Age  SibSp  Parch Ticket  Fare Cabin Embarked
# 630   male  80.0      0      0  27042  30.0   A23        S

# %%
data.loc[data['Age']==80]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#     Gender   Age  SibSp  Parch Ticket  Fare Cabin Embarked
# 630   male  80.0      0      0  27042  30.0   A23        S

# %%
data.loc[(data['Gender']=='male') & (data['Age']>40)]
# Out:
#      PassengerId  Survived  Pclass                            Name Gender  \
# 6              7         0       1         McCarthy, Mr. Timothy J   male
# 33            34         0       2           Wheadon, Mr. Edward H   male
# 35            36         0       1  Holverson, Mr. Alexander Oskar   male
# 54            55         0       1  Ostby, Mr. Engelhart Cornelius   male
# 62            63         0       1     Harris, Mr. Henry Birkhardt   male
# ..           ...       ...     ...                             ...    ...
# 845          846         0       3             Abbing, Mr. Anthony   male
# 851          852         0       3             Svensson, Mr. Johan   male
# 857          858         1       1          Daly, Mr. Peter Denis    male
# 860          861         0       3         Hansen, Mr. Claus Peter   male
# 873          874         0       3     Vander Cruyssen, Mr. Victor   male
#
#       Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# ...

# %%
data.loc[(data['Gender']=='female') & (data['Pclass']==1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 11            12         1       1
# 31            32         1       1
# 52            53         1       1
# ..           ...       ...     ...
# 856          857         1       1
# 862          863         1       1
# 871          872         1       1
# 879          880         1       1
# 887          888         1       1
#
#                                                   Name  Gender   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.loc[2]
# Out:
# PassengerId                         3
# Survived                            1
# Pclass                              3
# Name           Heikkinen, Miss. Laina
# Gender                         female
# Age                              26.0
# SibSp                               0
# Parch                               0
# Ticket               STON/O2. 3101282
# Fare                            7.925
# Cabin                             NaN
# Embarked                            S
# Name: 2, dtype: object

# %%
data.iloc[2]
# Out:
# PassengerId                         3
# Survived                            1
# Pclass                              3
# Name           Heikkinen, Miss. Laina
# Gender                         female
# Age                              26.0
# SibSp                               0
# Parch                               0
# Ticket               STON/O2. 3101282
# Fare                            7.925
# Cabin                             NaN
# Embarked                            S
# Name: 2, dtype: object

# %%
data.loc[np.where(data['Age']==80)]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#     Gender   Age  SibSp  Parch Ticket  Fare Cabin Embarked
# 630   male  80.0      0      0  27042  30.0   A23        S

# %%
data.iloc[np.where((data['Gender']=='male')&(data['Survived']==1))] ## no of male survived in titatinic using iloc
# Out:
#      PassengerId  Survived  Pclass                             Name Gender  \
# 17            18         1       2     Williams, Mr. Charles Eugene   male
# 21            22         1       2            Beesley, Mr. Lawrence   male
# 23            24         1       1     Sloper, Mr. William Thompson   male
# 36            37         1       3                 Mamee, Mr. Hanna   male
# 55            56         1       1                Woolner, Mr. Hugh   male
# ..           ...       ...     ...                              ...    ...
# 838          839         1       3                  Chip, Mr. Chang   male
# 839          840         1       1             Marechal, Mr. Pierre   male
# 857          858         1       1           Daly, Mr. Peter Denis    male
# 869          870         1       3  Johnson, Master. Harold Theodor   male
# 889          890         1       1            Behr, Mr. Karl Howell   male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# ...

# %%
data.loc[1,'Age']
# Out:
# 38.0

# %%
#data.loc[1,5] it support only string with num

# %%
data.iloc[1,5]
# Out:
# 38.0

# %%
#data.iloc[1,'Age'] it support only int value

# %%
data['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
data.Age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64
