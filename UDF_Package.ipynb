# %%
import simple as s

# %%
s.prime(7)
# Out:
# 'Prime Number'

# %%
s.CA(3.5)
# Out:
# 38.465

# %%
s.sqrt(7)
# Out:
# 2.6457513110645907

# %%
s.mylen("Data Engg Asso")
# Out:
# 14

# %%
help(s)
# Out:
# Help on module simple:
#
# NAME
#     simple - # coding: utf-8
#
# FUNCTIONS
#     CA(r)
#
#     mylen(data)
#
#     prime(n)
#
#     sqrt(n)
#
# FILE
#     c:\users\singh\cdewee31aug\simple.py
