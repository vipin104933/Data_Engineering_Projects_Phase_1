# %%
def prime(n):
    for i in range(2,n):
        if n%i==0:
            return "NOT Prime Number"
    else:
        return "Prime Number"

# %%
def CA(r):
    return 3.14*r*r

# %%
def mylen(data):
    c=0
    for i in data:
        c+=1
    return c

# %%
def sqrt(n):
    return n**0.5
